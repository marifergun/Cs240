# %%
import nsfg
import thinkstats2
import thinkplot
# %matplotlib inline
resp = nsfg.ReadFemResp()

# %%
resp.head(20)
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 7613    4640        5         5         6            5          5.0     18
# 7614    3998        5         5         2            5          5.0     24
# 7615    2432        5         5         5            5          5.0     15
# 7616    5438        1         5         3            5          5.0     30
# 7617    9643        1         5         2            5          5.0     24
# 7618    3030        1         5         1            5          5.0     34
# 7619   11585        1         5         4            5          5.0     34
# 7620    6677        1         5         4            1          5.0     26
# 7621   10744        5         5         8            5          1.0     22
# 7622    8403        5         5         4            5          5.0     19
# 7623    7574        5         5         4            5          5.0     19
# ...

# %%
resp.tail(30)
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 7613    4640        5         5         6            5          5.0     18
# 7614    3998        5         5         2            5          5.0     24
# 7615    2432        5         5         5            5          5.0     15
# 7616    5438        1         5         3            5          5.0     30
# 7617    9643        1         5         2            5          5.0     24
# 7618    3030        1         5         1            5          5.0     34
# 7619   11585        1         5         4            5          5.0     34
# 7620    6677        1         5         4            1          5.0     26
# 7621   10744        5         5         8            5          1.0     22
# 7622    8403        5         5         4            5          5.0     19
# 7623    7574        5         5         4            5          5.0     19
# ...

# %%
print "There are", len(resp.columns), "columns and", len(resp), "rows"
# Out:
# There are 3087 columns and 7643 rows

# %%
agescrn = resp.agescrn
print agescrn.value_counts().sort_index()
print "Oldest one is", max(agescrn), "years old"
print "Youngest one is", min(agescrn), "years old"
# Out:
# 15    217
# 16    223
# 17    234
# 18    235
# 19    241
# 20    258
# 21    267
# 22    287
# 23    282
# 24    269
# 25    267
# 26    260
# 27    255
# 28    252
# 29    262
# 30    292
# 31    278
# 32    273
# 33    257
# 34    255
# 35    262
# 36    266
# 37    271
# 38    256
# 39    215
# 40    256
# 41    250
# 42    215
# 43    253
# 44    235
# Name: agescrn, dtype: int64
# oldest one is 44 years old
# youngest one is 15 years old

# %%
pres[pres.agescrn<=25].numpregs.mean()
# Out:
# 0.70914326853851695

# %%
fmarno = resp.fmarno

# %%
fmarno.value_counts()
# Out:
# 0    3517
# 1    3436
# 2     582
# 3      90
# 4      15
# 5       3
# Name: fmarno, dtype: int64

# %%
hist = thinkstats2.Hist(fmarno, label="fmarno")

# %%
width = 0.5
thinkplot.Hist(hist, width = width)
thinkplot.Config(xlabel="Number of mariage", ylabel="Count")

# %%
nevermarried = resp[resp.fmarno==0]
married = resp[resp.fmarno>0]

# %%
hist1 = thinkstats2.Hist(nevermarried.totincr, label="nevermarried")
hist2 = thinkstats2.Hist(married.totincr, label="married")

# %%
thinkplot.PrePlot(2)
thinkplot.Hist(hist1, align='right', width=width)
thinkplot.Hist(hist2, align='left', width=width)
thinkplot.Config(xlabel='Total income', ylabel='Count')

# %%
std = nevermarried.totincr.std()
stdm = married.totincr.std() 
mean = nevermarried.totincr.mean()
meanm = married.totincr.mean()
var = nevermarried.totincr.var()
varm = married.totincr.var()
print "Standard deviation of nevermarrieds total income is %s" %(std)
print "Standard deviation of marrieds total income is %s" %(stdm)
print "Mean of nevermarrieds total income is %s" %(mean)
print "Mean of marrieds total income is %s" %(meanm)
print "Variance of nevermarrieds total income is %s" %(var)
print "Variance of marrieds total income is %s" %(varm)
# Out:
# Standard deviation of nevermarrieds total income is 3.98080879683
# Standard deviation of marrieds total income is 3.7146524958
# Mean of nevermarrieds total income is 8.02075632641
# Mean of marrieds total income is 9.49515269026
# Variance of nevermarrieds total income is 15.846838677
# Variance of marrieds total income is 13.7986431646
